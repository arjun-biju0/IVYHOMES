# %%
import requests
import time
import string
import json
from collections import deque

BASE_URL = "http://35.200.185.69:8000/v2/autocomplete"

MAX_RESULTS_PER_QUERY = 12
REQUEST_DELAY = 1.2
RETRY_DELAY = 5      
SAVE_INTERVAL = 100

seenNames = set()
visitedWords = set()
count = 0

RESULTS_FILE = "v2_names.json"

try:
    with open(RESULTS_FILE, "r") as f:
        seenNames = set(json.load(f))
        print(f"Loaded {len(seenNames)} names from previous run.")
except FileNotFoundError:
    pass

CHARSET = string.ascii_lowercase + string.digits

def search_api(prefix):
    global count
    while True:
        try:
            response = requests.get(BASE_URL, params={"query": prefix})
            count += 1

            if response.status_code == 429:
                print("Rate limit exceeded. Sleeping before retrying...")
                time.sleep(RETRY_DELAY)
                continue

            response.raise_for_status()
            data = response.json()
            return data.get("results", [])
        except Exception as e:
            print(f"Error: {e}. Retrying in {RETRY_DELAY} seconds...")
            time.sleep(RETRY_DELAY)


def mainFunction():
    queue = deque(CHARSET)

    while queue:
        prefix = queue.popleft()
        if prefix in visitedWords:
            continue
        visitedWords.add(prefix)

        results = search_api(prefix)
        time.sleep(REQUEST_DELAY)

        newNames = [name for name in results if name not in seenNames]
        seenNames.update(newNames)

        if len(results) == MAX_RESULTS_PER_QUERY:
            for c in CHARSET:
                new_prefix = prefix + c
                if new_prefix not in visitedWords:
                    queue.append(new_prefix)

        if count % SAVE_INTERVAL == 0:
            save_results()

    # Final save
    save_results()


def save_results():
    with open(RESULTS_FILE, "w") as f:
        json.dump(sorted(seenNames), f, indent=2)
    print(f"Saved {len(seenNames)} names after {count} requests.")


if __name__ == "__main__":
    mainFunction()
# Out:
# Saved 815 names after 100 requests.
# Saved 1410 names after 200 requests.
# Saved 1983 names after 300 requests.
# Saved 2513 names after 400 requests.
# Saved 3074 names after 500 requests.
# Saved 3636 names after 600 requests.
# Saved 4207 names after 700 requests.
# Saved 4769 names after 800 requests.
# Saved 5392 names after 900 requests.
# Saved 5966 names after 1000 requests.
# Saved 6563 names after 1100 requests.
# Saved 7153 names after 1200 requests.
# Saved 7699 names after 1300 requests.
# Saved 7879 names after 1400 requests.
# Saved 7885 names after 1500 requests.
# Saved 7887 names after 1600 requests.
# Saved 7890 names after 1700 requests.
# Saved 7903 names after 1800 requests.
# Saved 7908 names after 1900 requests.
# Saved 8204 names after 2000 requests.
# Saved 8212 names after 2100 requests.
# Saved 8503 names after 2200 requests.
# Saved 8511 names after 2300 requests.
# Saved 8524 names after 2400 requests.
# Saved 8533 names after 2500 requests.
# Saved 8839 names after 2600 requests.
# Saved 9133 names after 2700 requests.
# Saved 9134 names after 2800 requests.
# Saved 9138 names after 2900 requests.
# Saved 9138 names after 3000 requests.
# Saved 9140 names after 3100 requests.
# Saved 9141 names after 3200 requests.
# Saved 9426 names after 3300 requests.
# Saved 9428 names after 3400 requests.
# Saved 9996 names after 3500 requests.
# Saved 9996 names after 3600 requests.
# Saved 9998 names after 3700 requests.
# Saved 10001 names after 3800 requests.
# Saved 10110 names after 3900 requests.
# Saved 10285 names after 4000 requests.
# Saved 10288 names after 4100 requests.
# Saved 10488 names after 4200 requests.
# Saved 10574 names after 4300 requests.
# Saved 10574 names after 4400 requests.
# Saved 10856 names after 4500 requests.
# Saved 11141 names after 4600 requests.
# Saved 11141 names after 4700 requests.
# Saved 11423 names after 4800 requests.
# Saved 11427 names after 4900 requests.
# Saved 11427 names after 5000 requests.
# Saved 11625 names after 5100 requests.
# Saved 11985 names after 5200 requests.
# Saved 11990 names after 5300 requests.
# Saved 12274 names after 5400 requests.
# Saved 12560 names after 5500 requests.
# Saved 12560 names after 5600 requests.
# Saved 12563 names after 5700 requests.
# Saved 12567 names after 5800 requests.
# Saved 12851 names after 5900 requests.
# Saved 12852 names after 6000 requests.
# Saved 12996 names after 6100 requests.
# Saved 13139 names after 6200 requests.
# Saved 13419 names after 6300 requests.
# Saved 13420 names after 6400 requests.
# Saved 13423 names after 6500 requests.
# Saved 13429 names after 6600 requests.
# Saved 13712 names after 6700 requests.
# Saved 13714 names after 6800 requests.
# Saved 13714 names after 6900 requests.
# Saved 13715 names after 7000 requests.
# Saved 13718 names after 7100 requests.
# Saved 13725 names after 7200 requests.
# Saved 13727 names after 7300 requests.
# Saved 13728 names after 7400 requests.
# Saved 13730 names after 7416 requests.
