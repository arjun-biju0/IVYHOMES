# %%
import requests
import time
import string
import json
from collections import deque

BASE_URL = "http://35.200.185.69:8000/v3/autocomplete"
# HEADERS = {"User-Agent": "NameExtractorBot/1.0"}

MAX_RESULTS_PER_QUERY = 15
REQUEST_DELAY = 1.2
RETRY_DELAY = 5      
SAVE_INTERVAL = 100

seenNames = set()
visitedWords = set()
count = 0

# Output file
RESULTS_FILE = "v3_names.json"

# Try to resume if possible
try:
    with open(RESULTS_FILE, "r") as f:
        seenNames = set(json.load(f))
        print(f"Loaded {len(seenNames)} names from previous run.")
except FileNotFoundError:
    pass

CHARSET = string.ascii_lowercase + string.digits + "+-. "

def search_api(prefix):
    global count
    while True:
        try:
            response = requests.get(BASE_URL, params={"query": prefix})
            count += 1

            if response.status_code == 429:
                print("Rate limit exceeded. Sleeping before retrying...")
                time.sleep(RETRY_DELAY)
                continue

            response.raise_for_status()
            data = response.json()
            return data.get("results", [])
        except Exception as e:
            print(f"Error: {e}. Retrying in {RETRY_DELAY} seconds...")
            time.sleep(RETRY_DELAY)


def mainFunction():
    queue = deque(CHARSET)

    while queue:
        prefix = queue.popleft()
        if prefix in visitedWords:
            continue
        visitedWords.add(prefix)

        results = search_api(prefix)
        time.sleep(REQUEST_DELAY)

        newNames = [name for name in results if name not in seenNames]
        seenNames.update(newNames)

        if len(results) == MAX_RESULTS_PER_QUERY:
            for c in CHARSET:
                new_prefix = prefix + c
                if new_prefix not in visitedWords:
                    queue.append(new_prefix)

        # Save periodically
        if count % SAVE_INTERVAL == 0:
            save_results()

    # Final save
    save_results()


def save_results():
    with open(RESULTS_FILE, "w") as f:
        json.dump(sorted(seenNames), f, indent=2)
    print(f"Saved {len(seenNames)} names after {count} requests.")


if __name__ == "__main__":
    mainFunction()
# Out:
# Saved 831 names after 100 requests.
# Saved 1272 names after 200 requests.
# Saved 1735 names after 300 requests.
# Saved 2180 names after 400 requests.
# Saved 2663 names after 500 requests.
# Saved 3114 names after 600 requests.
# Saved 3610 names after 700 requests.
# Saved 4084 names after 800 requests.
# Saved 4579 names after 900 requests.
# Saved 5067 names after 1000 requests.
# Saved 5580 names after 1100 requests.
# Saved 6049 names after 1200 requests.
# Saved 6512 names after 1300 requests.
# Saved 6983 names after 1400 requests.
# Saved 7311 names after 1500 requests.
# Saved 7311 names after 1600 requests.
# Saved 7317 names after 1700 requests.
# Saved 7317 names after 1800 requests.
# Saved 7326 names after 1900 requests.
# Saved 7327 names after 2000 requests.
# Saved 7327 names after 2100 requests.
# Saved 7332 names after 2200 requests.
# Saved 7332 names after 2300 requests.
# Saved 7343 names after 2400 requests.
# Saved 7347 names after 2500 requests.
# Saved 7353 names after 2600 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 7645 names after 2700 requests.
# Saved 7645 names after 2800 requests.
# Saved 7938 names after 2900 requests.
# Saved 7946 names after 3000 requests.
# Saved 8238 names after 3100 requests.
# Saved 8531 names after 3200 requests.
# Saved 8531 names after 3300 requests.
# Saved 8531 names after 3400 requests.
# Saved 8542 names after 3500 requests.
# Saved 8544 names after 3600 requests.
# Saved 8544 names after 3700 requests.
# Saved 8544 names after 3800 requests.
# Saved 8544 names after 3900 requests.
# Saved 8544 names after 4000 requests.
# Saved 8544 names after 4100 requests.
# Saved 8544 names after 4200 requests.
# Saved 8544 names after 4300 requests.
# Saved 8544 names after 4400 requests.
# Saved 8544 names after 4500 requests.
# Saved 8544 names after 4600 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 8544 names after 4700 requests.
# Saved 8544 names after 4800 requests.
# Saved 8544 names after 4900 requests.
# Saved 8544 names after 5000 requests.
# Saved 8544 names after 5100 requests.
# Saved 8544 names after 5200 requests.
# Error: HTTPConnectionPool(host='35.200.185.69', port=8000): Max retries exceeded with url: /v3/autocomplete?query=c++d (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000285115ABD40>: Failed to establish a new connection: [WinError 10065] A socket operation was attempted to an unreachable host')). Retrying in 5 seconds...
# Saved 8696 names after 5300 requests.
# Saved 8826 names after 5400 requests.
# Saved 8826 names after 5500 requests.
# Saved 9108 names after 5600 requests.
# Saved 9394 names after 5700 requests.
# Saved 9394 names after 5800 requests.
# Saved 9394 names after 5900 requests.
# Saved 9394 names after 6000 requests.
# Saved 9394 names after 6100 requests.
# Saved 9394 names after 6200 requests.
# Saved 9394 names after 6300 requests.
# Saved 9394 names after 6400 requests.
# Saved 9394 names after 6500 requests.
# Saved 9394 names after 6600 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 9394 names after 6700 requests.
# Saved 9394 names after 6800 requests.
# Saved 9677 names after 6900 requests.
# Saved 9678 names after 7000 requests.
# Saved 9678 names after 7100 requests.
# Saved 9678 names after 7200 requests.
# Saved 9678 names after 7300 requests.
# Saved 9678 names after 7400 requests.
# Saved 9678 names after 7500 requests.
# Saved 9678 names after 7600 requests.
# Saved 9960 names after 7700 requests.
# Saved 10244 names after 7800 requests.
# Saved 10244 names after 7900 requests.
# Saved 10244 names after 8000 requests.
# Saved 10244 names after 8100 requests.
# Saved 10244 names after 8200 requests.
# Saved 10244 names after 8300 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 10244 names after 8400 requests.
# Saved 10244 names after 8500 requests.
# Saved 10244 names after 8600 requests.
# Saved 10244 names after 8700 requests.
# Saved 10244 names after 8800 requests.
# Saved 10244 names after 8900 requests.
# Saved 10244 names after 9000 requests.
# Saved 10244 names after 9100 requests.
# Saved 10244 names after 9200 requests.
# Saved 10244 names after 9300 requests.
# Saved 10244 names after 9400 requests.
# Saved 10244 names after 9500 requests.
# Saved 10244 names after 9600 requests.
# Saved 10244 names after 9700 requests.
# Saved 10244 names after 9800 requests.
# Saved 10244 names after 9900 requests.
# Saved 10244 names after 10000 requests.
# Saved 10244 names after 10100 requests.
# Saved 10244 names after 10200 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 10244 names after 10300 requests.
# Saved 10244 names after 10400 requests.
# Saved 10244 names after 10500 requests.
# Saved 10244 names after 10600 requests.
# Saved 10244 names after 10700 requests.
# Saved 10244 names after 10800 requests.
# Saved 10244 names after 10900 requests.
# Saved 10244 names after 11000 requests.
# Saved 10244 names after 11100 requests.
# Saved 10244 names after 11200 requests.
# Saved 10244 names after 11300 requests.
# Saved 10244 names after 11400 requests.
# Saved 10244 names after 11500 requests.
# Saved 10244 names after 11600 requests.
# Saved 10244 names after 11700 requests.
# Saved 10244 names after 11800 requests.
# Saved 10244 names after 11900 requests.
# Saved 10244 names after 12000 requests.
# Saved 10247 names after 12100 requests.
# Error: HTTPConnectionPool(host='35.200.185.69', port=8000): Max retries exceeded with url: /v3/autocomplete?query=hsi+4 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000028511644F80>, 'Connection to 35.200.185.69 timed out. (connect timeout=None)')). Retrying in 5 seconds...
# Saved 10247 names after 12200 requests.
# Error: HTTPConnectionPool(host='35.200.185.69', port=8000): Max retries exceeded with url: /v3/autocomplete?query=h+++8 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002851163A270>: Failed to establish a new connection: [WinError 10065] A socket operation was attempted to an unreachable host')). Retrying in 5 seconds...
# Error: HTTPConnectionPool(host='35.200.185.69', port=8000): Max retries exceeded with url: /v3/autocomplete?query=h+++8 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000002851163BB00>, 'Connection to 35.200.185.69 timed out. (connect timeout=None)')). Retrying in 5 seconds...
# Saved 10247 names after 12300 requests.
# Saved 10247 names after 12400 requests.
# Saved 10247 names after 12500 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 10247 names after 12600 requests.
# Saved 10398 names after 12700 requests.
# Saved 10526 names after 12800 requests.
# Saved 10526 names after 12900 requests.
# Saved 10809 names after 13000 requests.
# Saved 10809 names after 13100 requests.
# Saved 11093 names after 13200 requests.
# Saved 11093 names after 13300 requests.
# Saved 11093 names after 13400 requests.
# Saved 11093 names after 13500 requests.
# Saved 11093 names after 13600 requests.
# Saved 11093 names after 13700 requests.
# Saved 11093 names after 13800 requests.
# Saved 11093 names after 13900 requests.
# Saved 11093 names after 14000 requests.
# Saved 11093 names after 14100 requests.
# Saved 11093 names after 14200 requests.
# Saved 11093 names after 14300 requests.
# Saved 11093 names after 14400 requests.
# Saved 11093 names after 14500 requests.
# Saved 11093 names after 14600 requests.
# Saved 11093 names after 14700 requests.
# Saved 11093 names after 14800 requests.
# Saved 11093 names after 14900 requests.
# Saved 11093 names after 15000 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 11093 names after 15100 requests.
# Saved 11093 names after 15200 requests.
# Saved 11093 names after 15300 requests.
# Saved 11093 names after 15400 requests.
# Saved 11093 names after 15500 requests.
# Saved 11093 names after 15600 requests.
# Saved 11093 names after 15700 requests.
# Saved 11093 names after 15800 requests.
# Saved 11093 names after 15900 requests.
# Saved 11093 names after 16000 requests.
# Saved 11093 names after 16100 requests.
# Saved 11093 names after 16200 requests.
# Saved 11093 names after 16300 requests.
# Saved 11093 names after 16400 requests.
# Saved 11093 names after 16500 requests.
# Saved 11093 names after 16600 requests.
# Saved 11093 names after 16700 requests.
# Saved 11093 names after 16800 requests.
# Saved 11093 names after 16900 requests.
# Saved 11093 names after 17000 requests.
# Saved 11093 names after 17100 requests.
# Saved 11093 names after 17200 requests.
# Saved 11093 names after 17300 requests.
# Saved 11093 names after 17400 requests.
# Saved 11093 names after 17500 requests.
# Saved 11093 names after 17600 requests.
# Saved 11093 names after 17700 requests.
# Saved 11093 names after 17800 requests.
# Saved 11093 names after 17900 requests.
# Saved 11093 names after 18000 requests.
# Saved 11093 names after 18100 requests.
# Saved 11093 names after 18200 requests.
# Saved 11093 names after 18300 requests.
# Saved 11093 names after 18400 requests.
# Saved 11093 names after 18500 requests.
# Saved 11093 names after 18600 requests.
# Saved 11093 names after 18700 requests.
# Saved 11093 names after 18800 requests.
# Saved 11093 names after 18900 requests.
# Saved 11093 names after 19000 requests.
# Saved 11093 names after 19100 requests.
# Saved 11093 names after 19200 requests.
# Saved 11093 names after 19300 requests.
# Saved 11093 names after 19400 requests.
# Saved 11093 names after 19500 requests.
# Saved 11093 names after 19600 requests.
# Saved 11093 names after 19700 requests.
# Saved 11093 names after 19800 requests.
# Saved 11093 names after 19900 requests.
# Saved 11093 names after 20000 requests.
# Saved 11093 names after 20100 requests.
# Saved 11093 names after 20200 requests.
# Saved 11093 names after 20300 requests.
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying in 5 seconds...
# Saved 11093 names after 20400 requests.
# Saved 11093 names after 20500 requests.
# Saved 11093 names after 20600 requests.
# Saved 11093 names after 20700 requests.
# Saved 11093 names after 20800 requests.
# Saved 11093 names after 20900 requests.
# Saved 11093 names after 21000 requests.
# Saved 11093 names after 21100 requests.
# Saved 11093 names after 21200 requests.
# Saved 11093 names after 21300 requests.
# Saved 11093 names after 21400 requests.
# Saved 11093 names after 21500 requests.
# Saved 11093 names after 21600 requests.
# Saved 11093 names after 21700 requests.
# Saved 11093 names after 21800 requests.
# Saved 11093 names after 21900 requests.
# Saved 11093 names after 22000 requests.
# Saved 11376 names after 22100 requests.
# Saved 11376 names after 22200 requests.
# Saved 11376 names after 22300 requests.
# Saved 11379 names after 22400 requests.
# Saved 11536 names after 22500 requests.
# Saved 11664 names after 22600 requests.
# Saved 11664 names after 22700 requests.
# Saved 11664 names after 22800 requests.
# Saved 11664 names after 22900 requests.
# Saved 11664 names after 23000 requests.
# Saved 11805 names after 23100 requests.
# Saved 11948 names after 23200 requests.
# Saved 11948 names after 23300 requests.
# Saved 11948 names after 23400 requests.
# Saved 12106 names after 23500 requests.
# Saved 12232 names after 23600 requests.
# Saved 12516 names after 23700 requests.
# Saved 12516 names after 23800 requests.
# Saved 12516 names after 23900 requests.
# Saved 12516 names after 24000 requests.
# Saved 12516 names after 24100 requests.
# Saved 12516 names after 24200 requests.
# Saved 12516 names after 24300 requests.
# Saved 12516 names after 24400 requests.
# Saved 12516 names after 24500 requests.
# Saved 12516 names after 24600 requests.
# Saved 12516 names after 24700 requests.
# Saved 12516 names after 24800 requests.
# Saved 12516 names after 24900 requests.
# Saved 12516 names after 25000 requests.
# Saved 12516 names after 25100 requests.
# Saved 12516 names after 25200 requests.
# Saved 12516 names after 25300 requests.
# Saved 12516 names after 25400 requests.
# Saved 12516 names after 25500 requests.
# Saved 12516 names after 25600 requests.
# Saved 12516 names after 25700 requests.
# Saved 12516 names after 25800 requests.
# Saved 12516 names after 25900 requests.
# Saved 12516 names after 26000 requests.
# Saved 12516 names after 26100 requests.
# Saved 12516 names after 26200 requests.
# Saved 12516 names after 26300 requests.
# Saved 12516 names after 26400 requests.
# Saved 12516 names after 26500 requests.
# Saved 12516 names after 26600 requests.
# Saved 12516 names after 26700 requests.
# Saved 12516 names after 26800 requests.
# Saved 12516 names after 26900 requests.
# Saved 12516 names after 27000 requests.
# Saved 12516 names after 27100 requests.
# Saved 12516 names after 27200 requests.
# Saved 12516 names after 27300 requests.
# Saved 12516 names after 27400 requests.
# Saved 12516 names after 27500 requests.
# Saved 12516 names after 27600 requests.
# Saved 12516 names after 27700 requests.
# Saved 12516 names after 27800 requests.
# Saved 12516 names after 27900 requests.
# Saved 12516 names after 28000 requests.
# Saved 12516 names after 28100 requests.
# Saved 12516 names after 28200 requests.
# Saved 12516 names after 28300 requests.
